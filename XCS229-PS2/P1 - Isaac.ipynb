# %%
import src.util as util
import numpy as np
import matplotlib.pyplot as plt

# %%
Xa, Ya = util.load_csv('./data/ds1_a.csv', add_intercept=False)
Xb, Yb = util.load_csv('./data/ds1_b.csv', add_intercept=False)

Xa_pos = Xa[Ya == 1]
Xa_neg = Xa[Ya == -1]

Xb_pos = Xb[Yb == 1]
Xb_neg = Xb[Yb == -1]

# %%
plt.scatter(Xa_pos[:,0], Xa_pos[:,1], marker='x', color='red')
plt.scatter(Xa_neg[:,0], Xa_neg[:,1], marker='o', color='blue')

# %%
plt.scatter(Xb_pos[:,0], Xb_pos[:,1], marker='x', color='red')
plt.scatter(Xb_neg[:,0], Xb_neg[:,1], marker='o', color='blue')
